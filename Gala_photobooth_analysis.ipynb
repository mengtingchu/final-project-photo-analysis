# %%
import pandas as pd
import matplotlib
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Part 1
# ## Download the images from the website

# %% [markdown]
# # Part 2
# ## Detect number of people on every picture

# %% [markdown]
# Hey you can see in this first image all the faces were detected except that one girl on the left because her face is cropped
# <img src="image1.png" alt="drawing" width="400"/>
#
# On the second image you can see that the grey scarf was detected with a 52% probability and our threshold was 50%. So this is a false positive. The problem is, if we increase the detection threshold, some faces won't be detected, like the guy on top with 58%
# <img src="image2.png" alt="drawing" width="400"/>
#
# The two following pictures are the same, nothing was detected with a 50% threshold so we cut it to 10%
# <img src="image3.png" alt="drawing" width="400"/>
# <img src="image4.png" alt="drawing" width="400"/>

# %% [markdown]
# # Part 3
# ## Hourly analysis of the number of people using the photobooth

# %%
df = pd.read_csv('analysis_results.csv', index_col = 0)

# %%
df.head()
# Out:
#    1_23-24  2_24-01  3_01-02  4_02-03  4_03-04  5_04-05  6_05-06
# 0        7        2        1        5        1        3        2
# 1        6        2        2        5        1        0        2
# 2        9        2        1        5        2        2        0
# 3        2        2        1        3        2        3        2
# 4        2        1        1        3        1        3        0

# %%
df.describe().applymap(round)
# Out:
#        1_23-24  2_24-01  3_01-02  4_02-03  4_03-04  5_04-05  6_05-06
# count      168      168      168      168      168      168      168
# mean         4        3        4        3        3        3        2
# std          2        2        2        2        2        2        1
# min          0        0        0        0        0        0        0
# 25%          2        2        3        2        2        2        1
# 50%          3        3        3        2        2        2        2
# 75%          5        5        5        3        4        4        2
# max         13        9       11        9        9       10        6

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='Red', caps='Black')
df.plot.box(color=color, sym='r+', figsize = (15,9))

# %%
hist = df.plot.hist(bins = 13, figsize = (15,9))

# %%
df = pd.DataFrame(df.values.ravel())
df.rolling(window = 5).mean().plot(figsize=(9,9))
